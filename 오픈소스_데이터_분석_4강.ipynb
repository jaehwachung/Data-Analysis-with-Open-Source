# %% [markdown]
# <a href="https://colab.research.google.com/github/jaehwachung/Data-Analysis-with-Open-Source/blob/main/%EC%98%A4%ED%94%88%EC%86%8C%EC%8A%A4_%EB%8D%B0%EC%9D%B4%ED%84%B0_%EB%B6%84%EC%84%9D_4%EA%B0%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 오픈소스 기반 데이터 분석 4강 - 데이터 수집

# %% [markdown]
# ## 4-1 CSV 파일 읽기

# %%
import pandas as pd

## data.csv 파일 읽기
df = pd.read_csv('./"Chapter 3"/data.csv', encoding='utf-8',sep=',',header=0, index_col=0)

print(df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 4
#       1 import pandas as pd
#       3 ## data.csv 파일 읽기
# ----> 4 df = pd.read_csv('./"Chapter 3"/data.csv', encoding='utf-8',sep=',',header=0, index_col=0)
#       6 print(df)
#
# ...

# %% [markdown]
# ## 4-2 JSON 파일 읽기

# %%
import json
import pandas as pd
with open('./Chapter 3/data.json', mode='r', encoding='utf-8') as f:
    data = json.load(f)
    print(data)

## data.json 파일 출력

## data.json 파일 DataFrame 읽기
df = pd.read_json('./Chapter 3/data.json', orient='records',lines=False, encoding='utf-8')
print(df)
# Out:
# {'매출데이터': [{'월': '2025-01', '매출액': 1000000, '비용': 700000, '이익': 300000}, {'월': '2025-02', '매출액': 1200000, '비용': 800000, '이익': 400000}, {'월': '2025-03', '매출액': 1500000, '비용': 900000, '이익': 600000}]}
#                                                매출데이터
# 0  {'월': '2025-01', '매출액': 1000000, '비용': 700000,...
# 1  {'월': '2025-02', '매출액': 1200000, '비용': 800000,...
# 2  {'월': '2025-03', '매출액': 1500000, '비용': 900000,...

# %% [markdown]
# ## 4-3 텍스트 파일 읽기 및 데이터 추출

# %%
import re

## 파일(callcenter20250301.log) 오픈 및 읽기
with open('./Chapter 3/callcenter20250301.log', 'r', encoding='utf-8') as f:
    content = f.read()

print(content)
## 주민등록번호 패턴 생성
pattern = re.compile(r'(\d{6})-?(\d{7})')

## 주민등록번호 마스킹
masked_content = pattern.sub(r'\1-*******', content)

## 마스킹된 파일(callcenter20250301_masked.log) 오픈 및 쓰기
with open('./Chapter 3/callcenter_masked.log',mode='w') as f:
    f.write(masked_content)

print("주민등록번호 마스킹 완료. 'callcenter20250301_masked.log.txt' 파일로 저장되었습니다.")
# Out:
# 고객상담 내역 기록 - 2025년 3월 1일
# [09:15] 홍길동 고객(ID: K12345) 문의접수
# 주문번호: ORDER-20250301-001
# 연락처: 010-1234-5678
# 주소: 서울시 강남구 테헤란로 123
# 주민등록번호: 880412-1234567
# 문의내용: 주문한 상품의 배송 지연 문의
# [10:30] 김철수 고객(ID: K67890) 문의접수
# 주문번호: ORDER-20250301-002
# 연락처: 010-9876-5432
# 주소: 부산시 해운대구 해운대로 456
# 주민등록번호: 910725-2345678
# 문의내용: 제품 교환 요청
# [11:45] 이영희 고객(ID: K24680) 문의접수
# 주문번호: ORDER-20250301-003
# 연락처: 010-1357-2468
# 주소: 대구시 수성구 수성로 789
# 주민등록번호: 850608-2456789
# 문의내용: 포인트 적립 관련 문의
# [14:20] 박민준 고객(ID: K13579) 문의접수
# 주문번호: ORDER-20250301-004
# 연락처: 010-2468-1357
# 주소: 인천시 연수구 컨벤시아대로 321
# 주민등록번호: 930217-1234567
# 문의내용: 회원 정보 수정 요청
# [15:40] 정수연 고객(ID: K97531) 문의접수
# 주문번호: ORDER-20250301-005
# 연락처: 010-8642-9753
# 주소: 광주시 서구 상무중앙로 654
# 주민등록번호: 890503-4567123
# 문의내용: 결제 취소 요청
#
# 주민등록번호 마스킹 완료. 'callcenter20250301_masked.log.txt' 파일로 저장되었습니다.

# %% [markdown]
# ## 4-4 Open-Meteo의 무료 날씨 API를 통한 특정 지역 온도 조회

# %%
import requests
import json

url = "https://api.open-meteo.com/v1/forecast?=&=&current=temperature_2m"
params = {
    "latitude": "37.58638333",
    "longitude": "127.0203333",
    "current": "temperature_2m"
}

try:
    ## URL 및 파라미터 전송

    ## JSON 데이터 읽기

    print("API 응답:", data)
    print("서울시 종로구의 현재 온도는 : {0}{1} 입니다.".format(data['current']['temperature_2m'], data['current_units']['temperature_2m']))

except requests.exceptions.RequestException as e:
    print(f"API 호출 실패: {e}")
except json.JSONDecodeError as e:
    print(f"JSON 파싱 실패: {e}")

# %% [markdown]
# ## 4-5 Selenium과 lxml을 이용한 웹 스크래핑

# %%
# !curl -o google-chrome-stable_current_amd64.deb https://dl.google.com/linux/direct/google-chrome-stable_current_amd64.deb
# !apt install ./google-chrome-stable_current_amd64.deb -y
# !pip install selenium webdriver_manager

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service as ChromeService
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from lxml import html
import time

chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument('--headless')               # 브라우저 창 없이 실행
chrome_options.add_argument('--no-sandbox')             # 보안모드 비활성화 (Colab 필수)
chrome_options.add_argument('--disable-dev-shm-usage')  # 메모리 부족 방지 (Colab 필수)
chrome_options.add_argument('--window-size=1920x1080')  # 창 크기 설정(가상)
chrome_options.add_argument('--disable-gpu')            # GPU 가속 비활성화 (일부 환경 안정성)
chrome_options.binary_location = "/usr/bin/google-chrome-stable"  # Colab용 크롬 경로 지정

## 드라이버 실행
driver = webdriver.Chrome(options=chrome_options)

## 사이트 접속


## 사이트 접속 대기


## 페이지 제목 출력


## 드라이버 종료
driver.quit()

# %% [markdown]
# # 실습 시나리오

# %% [markdown]
# ## 공공데이터 포털 가입 및 데이터 신청
#
# - [https://www.data.go.kr](https://www.data.go.kr)
# - 한국환경공단 에어코리아 대기오염정보 데이터 신청

# %%
import requests

## 데이터 수집 url 및 api key 설정


params = {
    'serviceKey': api_key,
    'returnType': 'json',
    'numOfRows': '100',
    'pageNo': '1',
    'sidoName': '서울',
    'ver': '1.0'
}

## 데이터 수집

## 호출 성공/실패 출력
